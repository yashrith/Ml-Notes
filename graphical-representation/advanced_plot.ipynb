# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.rand(50,3), columns=['a','b','c'])
df.head()
# Out:
#           a         b         c
# 0  0.450264  0.009813  0.850562
# 1  0.156746  0.363144  0.639717
# 2  0.949356  0.941378  0.522972
# 3  0.685445  0.331741  0.668546
# 4  0.673927  0.183783  0.703427

# %%
plt.style.use('ggplot')

# %%
df.plot(kind='scatter', x='a', y='b', s=df['c']*200, color='green')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot(kind='area')
# Out:
# <Axes: >
